# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
tests = pd.read_csv('../data/Tests_Conducted_31Mar2020.csv')

# %%
tests
# Out:
#               Country or region   Tests  Positive   As of  Tests/ million  \
# 0                     Argentina    2847     589.0  27 Mar            63.0
# 1                       Armenia    1580     265.0  25 Mar           535.0
# 2                     Australia  245623    4559.0  31 Mar          9670.0
# 3                       Austria   46441    8536.0  29 Mar          5217.0
# 4                    Azerbaijan   30000     273.0  30 Mar          3031.0
# ..                          ...     ...       ...     ...             ...
# 102    United States:  Michigan   17379    5486.0  30 Mar          1734.0
# 103       United States:  Texas   35880    2877.0  30 Mar          1237.0
# 104  United States:  Washington   65462    4896.0  29 Mar          8597.0
# 105                     Uruguay    1538     189.0  24 Mar           443.0
# 106                     Vietnam   35808     207.0  31 Mar           369.0
#
#      Positive/ million             Ref.  \
# ...
